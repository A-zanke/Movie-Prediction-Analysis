# %% [markdown]
# <a href="https://colab.research.google.com/github/A-zanke/Movie-Prediction-Analysis/blob/main/Movie_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/IMDb Movies India.csv',na_values=(' '),encoding='latin-1')
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                 NaN     NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15508 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.isna().sum()
# Out:
# Name           1
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
# drop the duplicated rows
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Name','Duration'],axis=1,inplace=True)
df.head()
# Out:
#      Year            Genre  Rating Votes            Director       Actor 1  \
# 0     NaN            Drama     NaN   NaN       J.S. Randhawa      Manmauji
# 1  (2019)            Drama     7.0     8       Gaurav Bakshi  Rasika Dugal
# 2  (2021)   Drama, Musical     NaN   NaN  Soumyajit Majumdar  Sayani Gupta
# 3  (2019)  Comedy, Romance     4.4    35          Ovais Khan       Prateik
# 4  (2010)            Drama     NaN   NaN        Amol Palekar  Rajat Kapoor
#
#               Actor 2          Actor 3
# 0              Birbal  Rajendra Bhatia
# 1      Vivek Ghamande    Arvind Jangid
# 2   Plabita Borthakur       Roy Angana
# 3          Ishita Raj  Siddhant Kapoor
# 4  Rituparna Sengupta      Antara Mali

# %%
df.shape
# Out:
# (15503, 8)

# %%
## Drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Year         102
# Genre        485
# Rating        84
# Votes       2034
# Director    5938
# Actor 1     4718
# Actor 2     4891
# Actor 3     4820
# dtype: int64

# %%
cat = list(df.columns[df.dtypes=='object'])

# %%
mn = df['Rating'].mean()
df['Rating'].fillna(mn,inplace=True)

# %%
for i in cat:
    m = df[i].mode()[0]
    df[i].fillna(m,inplace=True)

# %%
df.isna().sum()
# Out:
# Year        0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
# Lets convert Date column from string to int
df['Year']= df['Year'].str.strip('()').astype(int)
# Lets convert Votes column from string to int
df['Votes'] = df['Votes'].str.replace(',','')
df['Votes'] = df['Votes'].str.replace('.','')
df['Votes'] = df['Votes'].str.strip('$')
df['Votes'] = df['Votes'].str.strip('M')
df['Votes'] = df['Votes'].astype(int)

# %%
df.nunique()
# Out:
# Year         102
# Genre        485
# Rating        85
# Votes       2034
# Director    5938
# Actor 1     4718
# Actor 2     4891
# Actor 3     4820
# dtype: int64

# %%
## performing mean encoding
df['Genre encoded'] = round(df.groupby('Genre')['Rating'].transform('mean'),1)
df['Votes encoded'] = round(df.groupby('Votes')['Rating'].transform('mean'),1)
df['Director encoded'] = round(df.groupby('Director')['Rating'].transform('mean'),1)
df['Actor 1 encoded'] = round(df.groupby('Actor 1')['Rating'].transform('mean'),1)
df['Actor 2 encoded'] = round(df.groupby('Actor 2')['Rating'].transform('mean'),1)
df['Actor 3 encoded'] = round(df.groupby('Actor 3')['Rating'].transform('mean'),1)

df.drop(columns=['Genre','Votes','Director','Actor 1','Actor 2','Actor 3'],inplace=True)
df['Rating'] = round(df['Rating'],1)
df.head()
# Out:
#    Year  Rating  Genre encoded  Votes encoded  Director encoded  \
# 0  2019     5.8            6.0            5.8               5.8
# 1  2019     7.0            6.0            5.8               7.0
# 2  2021     5.8            6.3            5.8               5.8
# 3  2019     4.4            5.7            5.9               4.4
# 4  2010     5.8            6.0            5.8               6.3
#
#    Actor 1 encoded  Actor 2 encoded  Actor 3 encoded
# 0              5.8              5.5              5.8
# 1              6.8              7.0              7.0
# 2              6.2              6.8              5.8
# 3              5.4              4.4              4.4
# 4              6.8              5.8              5.5

# %%
X = df.drop(columns='Rating')
Y =df[['Rating']]
X.head()
# Out:
#    Year  Genre encoded  Votes encoded  Director encoded  Actor 1 encoded  \
# 0  2019            6.0            5.8               5.8              5.8
# 1  2019            6.0            5.8               7.0              6.8
# 2  2021            6.3            5.8               5.8              6.2
# 3  2019            5.7            5.9               4.4              5.4
# 4  2010            6.0            5.8               6.3              6.8
#
#    Actor 2 encoded  Actor 3 encoded
# 0              5.5              5.8
# 1              7.0              7.0
# 2              6.8              5.8
# 3              4.4              4.4
# 4              5.8              5.5

# %%
Y.head()
# Out:
#    Rating
# 0     5.8
# 1     7.0
# 2     5.8
# 3     4.4
# 4     5.8

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X,Y,test_size=0.25,random_state=21)

# %%
xtrain.shape
# Out:
# (11325, 7)

# %%
xtest.shape
# Out:
# (3776, 7)

# %%
ytrain.shape
# Out:
# (11325, 1)

# %%
ytest.shape
# Out:
# (3776, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV

# %%
dct = {
    'Linear':LinearRegression(),
    'DecisionTree':DecisionTreeRegressor(),
    'RandomForest':RandomForestRegressor(),
    'GradientBoosting':GradientBoostingRegressor(),
    'KNN':KNeighborsRegressor(),
    'SVR':SVR()
}

# %%
dct.items()
# Out:
# dict_items([('Linear', LinearRegression()), ('DecisionTree', DecisionTreeRegressor()), ('RandomForest', RandomForestRegressor()), ('GradientBoosting', GradientBoostingRegressor()), ('KNN', KNeighborsRegressor()), ('SVR', SVR())])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score

# Ensure ytrain and ytest are 1D arrays
ytrain = ytrain.values.ravel()
ytest = ytest.values.ravel()

# Dictionary of models
dct = {
    'Linear': LinearRegression(),
    'DecisionTree': DecisionTreeRegressor(),
    'RandomForest': RandomForestRegressor(),
    'GradientBoosting': GradientBoostingRegressor(),
    'KNN': KNeighborsRegressor(),
    'SVR': SVR()
}

# Lists to store results
train_mse = []
train_r2 = []
test_mse = []
test_r2 = []
train_cv = []

for name, model in dct.items():
    # Fit the model
    m = model.fit(xtrain, ytrain)
    ypred_train = m.predict(xtrain)
    ypred_test = m.predict(xtest)

    # Calculate MSE
    mse_train = mean_squared_error(ytrain, ypred_train)
    mse_test = mean_squared_error(ytest, ypred_test)

    # Calculate R2
    r2_train = r2_score(ytrain, ypred_train) * 100
    r2_test = r2_score(ytest, ypred_test) * 100

    # Calculate cross-validated scores
    cv_scores = cross_val_score(m, xtrain, ytrain, cv=5, scoring='r2')
    cv_mean = cv_scores.mean() * 100

    # Add these values to the respective lists
    train_mse.append(mse_train)
    train_r2.append(r2_train)
    test_mse.append(mse_test)
    test_r2.append(r2_test)
    train_cv.append(cv_mean)

    # Print the results
    print(f'Scores for {name}')
    print("Training Scores")
    print(f'MSE: {mse_train:.4f}')
    print(f'R2: {r2_train:.2f}%')
    print("Testing Scores")
    print(f'MSE: {mse_test:.4f}')
    print(f'R2: {r2_test:.2f}%')
    print(f'Cross-Validated R2: {cv_mean:.2f}%')
    print("="*30)

# Summarize results
print("Summary of Results")
print(f"{'Model':<20} {'Train MSE':<10} {'Test MSE':<10} {'Train R2':<10} {'Test R2':<10} {'CV R2':<10}")
for i, name in enumerate(dct.keys()):
    print(f"{name:<20} {train_mse[i]:<10.4f} {test_mse[i]:<10.4f} {train_r2[i]:<10.2f}% {test_r2[i]:<10.2f}% {train_cv[i]:<10.2f}%")
# Out:
# Scores for Linear
# Training Scores
# MSE: 0.2467
# R2: 74.87%
# Testing Scores
# MSE: 0.2716
# R2: 74.40%
# Cross-Validated R2: 74.74%
# ==============================
# Scores for DecisionTree
# Training Scores
# MSE: 0.0002
# R2: 99.98%
# Testing Scores
# MSE: 0.4268
# R2: 59.77%
# Cross-Validated R2: 59.19%
# ==============================
# Scores for RandomForest
# Training Scores
# MSE: 0.0272
# R2: 97.23%
# Testing Scores
# MSE: 0.2204
# R2: 79.23%
# Cross-Validated R2: 79.79%
# ==============================
# Scores for GradientBoosting
# Training Scores
# MSE: 0.1902
# R2: 80.63%
# Testing Scores
# MSE: 0.2375
# R2: 77.61%
# Cross-Validated R2: 78.40%
# ==============================
# Scores for KNN
# Training Scores
# MSE: 0.1811
# R2: 81.56%
# Testing Scores
# MSE: 0.3083
# R2: 70.94%
# Cross-Validated R2: 71.40%
# ==============================
# Scores for SVR
# Training Scores
# MSE: 0.9793
# R2: 0.25%
# Testing Scores
# MSE: 1.0573
# R2: 0.34%
# Cross-Validated R2: 0.02%
# ==============================
# Summary of Results
# Model                Train MSE  Test MSE   Train R2   Test R2    CV R2
# Linear               0.2467     0.2716     74.87     % 74.40     % 74.74     %
# DecisionTree         0.0002     0.4268     99.98     % 59.77     % 59.19     %
# RandomForest         0.0272     0.2204     97.23     % 79.23     % 79.79     %
# GradientBoosting     0.1902     0.2375     80.63     % 77.61     % 78.40     %
# KNN                  0.1811     0.3083     81.56     % 70.94     % 71.40     %
# SVR                  0.9793     1.0573     0.25      % 0.34      % 0.02      %

# %%
res = {'Name':list(dct.keys()),
       'MSE Training Scores':train_mse,
       'MSE Testing Scores':test_mse,
       'R2 Training Scores':train_r2,
       'R2 Testing Scores':test_r2,
       'CV Training Scores':train_cv}

# %%
df_res = pd.DataFrame(res)
df_res.sort_values('CV Training Scores',ascending=False)
# Out:
#                Name  MSE Training Scores  MSE Testing Scores  \
# 2      RandomForest             0.027171            0.220362
# 3  GradientBoosting             0.190184            0.237487
# 0            Linear             0.246675            0.271591
# 4               KNN             0.181077            0.308273
# 1      DecisionTree             0.000214            0.426814
# 5               SVR             0.979322            1.057331
#
#    R2 Training Scores  R2 Testing Scores  CV Training Scores
# 2           97.232472          79.228619           79.787632
# 3           80.628352          77.614399           78.403164
# 0           74.874221          74.399768           74.739503
# 4           81.555872          70.942065           71.396913
# 1           99.978234          59.768388           59.192532
# 5            0.248540           0.335717            0.023700

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Define the parameter grid for RandomizedSearchCV
params = {
    'n_estimators': [100, 200, 300],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize the RandomForestRegressor
rfr = RandomForestRegressor()

# Set up RandomizedSearchCV
rscv = RandomizedSearchCV(
    estimator=rfr,
    param_distributions=params,
    n_iter=10,  # Number of parameter settings that are sampled
    cv=3,  # Number of cross-validation folds
    scoring='neg_mean_squared_error',
    n_jobs=-1,  # Use all available cores for parallel processing
    random_state=42  # Ensure reproducibility
)

# Fit the RandomizedSearchCV
rscv.fit(xtrain, ytrain)

# Print the best parameters and the corresponding score
print("Best parameters found: ", rscv.best_params_)
print("Best cross-validation score (neg MSE): ", rscv.best_score_)
# Out:
# Best parameters found:  {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 30, 'bootstrap': True}
# Best cross-validation score (neg MSE):  -0.19351115197243718

# %%
best_rfr = rscv.best_estimator_
best_rfr
# Out:
# RandomForestRegressor(max_depth=30, max_features='log2', min_samples_split=5,
#                       n_estimators=200)

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(xtrain,ytrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9250681221304905

# %%
model.score(xtest,ytest)
# Out:
# 0.7841636539213964

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV

# Define the model
model = XGBRegressor()

# Define the parameter grid
params = {
    'n_estimators': [200, 300, 500],
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [5, 6, 7],
    'min_child_weight': [1, 2],
    'objective': ['reg:squarederror'],
    'gamma': [0.1, 0.2]
}

# Initialize RandomizedSearchCV
gscv = RandomizedSearchCV(
    estimator=model,
    param_distributions=params,
    n_iter=20,  # Number of parameter settings that are sampled
    scoring='neg_mean_squared_error',
    cv=3,  # Number of cross-validation folds
    n_jobs=-1,  # Use all available cores for parallel processing
    random_state=42  # Ensure reproducibility
)

# Fit the RandomizedSearchCV
gscv.fit(xtrain, ytrain)

# Print the best parameters and the corresponding score
print("Best parameters found: ", gscv.best_params_)
print("Best cross-validation score (neg MSE): ", gscv.best_score_)
# Out:
# Best parameters found:  {'objective': 'reg:squarederror', 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0.1}
# Best cross-validation score (neg MSE):  -0.19368502018141606

# %%
gscv.best_params_
# Out:
# {'objective': 'reg:squarederror',
#  'n_estimators': 200,
#  'min_child_weight': 1,
#  'max_depth': 5,
#  'learning_rate': 0.05,
#  'gamma': 0.1}

# %%
best_xgb = gscv.best_estimator_
best_xgb
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
best_xgb.score(xtrain,ytrain)
# Out:
# 0.8520642612410755

# %%
best_xgb.score(xtest,ytest)
# Out:
# 0.8004218085721413

# %%
params1 = {'subsample':[0.5,0.6,0.7,0.8,0.9,1],
           'colsample_bytree':[0.5,0.6,0.7,0.8,0.9,1]}
gscv1 = RandomizedSearchCV(best_xgb,params1,cv=5,scoring='neg_mean_squared_error')
gscv1.fit(xtrain,ytrain)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=0.1, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=0...
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=5,
#                                           max_leaves=None, min_child_weight=1,
#                                           missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None, n_estimators=200,
#                                           n_jobs=None, num_parallel_tree=None,
#                                           random_state=None, ...),
#                    param_distributions={'colsample_bytree': [0.5, 0.6, 0.7, 0.8,
#                                                              0.9, 1],
#                                         'subsample': [0.5, 0.6, 0.7, 0.8, 0.9,
#                                                       1]},
#                    scoring='neg_mean_squared_error')

# %%
gscv1.best_params_
# Out:
# {'subsample': 0.8, 'colsample_bytree': 0.9}

# %%
best_xgb2 = gscv1.best_estimator_
best_xgb2
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
best_xgb2.score(xtrain,ytrain)
# Out:
# 0.8540090964664478

# %%
best_xgb2.score(xtest,ytest)
# Out:
# 0.8019812795554291

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
def eval_model(model,xtrain,ytrain):
    # Fit the model
    model.fit(xtrain,ytrain)
    # Predict the scores
    ypred_test = model.predict(xtest)
    # Calculate MSE,RMSE,MAE,R2 scores
    mse = mean_squared_error(ytest,ypred_test)
    rmse = mse**(1/2)
    mae = mean_absolute_error(ytest,ypred_test)
    r2 = r2_score(ytest,ypred_test)
    return mse,rmse,mae,r2

# %%
(MSE,RMSE,MAE,r2) = eval_model(best_rfr,xtrain,ytrain)
print(f'Evaluation Metrics: \nMSE: {MSE}\nRMSE:{RMSE}\nMAE:{MAE}\nR2:{r2}')
# Out:
# Evaluation Metrics:
# MSE: 0.21721507780490018
# RMSE:0.4660633838920412
# MAE:0.2558264262448335
# R2:0.7952524781838055

# %%
(MSE,RMSE,MAE,r2) = eval_model(best_xgb2,xtrain,ytrain)
print(f'Evaluation Metrics: \nMSE: {MSE}\nRMSE:{RMSE}\nMAE:{MAE}\nR2:{r2}')
# Out:
# Evaluation Metrics:
# MSE: 0.210076543963289
# RMSE:0.45834107819754605
# MAE:0.26286686550257565
# R2:0.8019812795554291

# %%
ypred_test = best_xgb2.predict(xtest)
ypred_test[:10]
# Out:
# array([6.883422 , 5.7724524, 4.292525 , 7.986285 , 5.8848057, 6.944228 ,
#        6.0400863, 5.5535975, 5.79521  , 4.81274  ], dtype=float32)

# %%
print(ytest[:10])
# Out:
# [7.1 5.8 3.7 8.  7.3 6.9 6.2 5.8 5.8 4.9]

# %%
df_final = xtest
df_final['Predicted_Rating'] = ypred_test
df_final
# Out:
#        Year  Genre encoded  Votes encoded  Director encoded  Actor 1 encoded  \
# 4806   2015            5.4            7.1               6.4              5.5
# 10573  1989            5.7            5.8               5.8              5.6
# 3674   2000            5.9            3.7               4.9              5.2
# 9179   1970            5.9            8.0               7.1              6.8
# 6229   2003            5.7            6.1               5.7              5.1
# ...     ...            ...            ...               ...              ...
# 5126   2007            5.8            5.7               5.6              5.7
# 5934   1971            5.8            6.2               6.0              6.4
# 15146  1972            5.3            5.7               5.8              5.3
# 14280  2010            6.0            6.2               5.7              5.1
# 4019   1994            5.8            5.4               4.1              2.7
#
#        Actor 2 encoded  Actor 3 encoded  Predicted_Rating
# 4806               6.2              5.7          6.883422
# 10573              5.8              5.8          5.772452
# 3674               5.8              5.8          4.292525
# 9179               6.8              6.8          7.986285
# 6229               5.6              6.9          5.884806
# ...                ...              ...               ...
# 5126               5.8              5.6          5.631411
# 5934               6.0              6.6          6.563365
# 15146              6.1              6.0          5.527514
# 14280              5.7              5.7          5.874767
# 4019               5.2              4.2          3.199581
#
# [3776 rows x 8 columns]

# %%
df_final.to_csv('Predicted Ratings.csv',index=False)
